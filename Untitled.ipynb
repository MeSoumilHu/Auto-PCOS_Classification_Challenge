# %%
'''1 - Packages'''
# for data load
import os

# for reading and processing images
import imageio.v2 as imageio

from PIL import Image

# for visualizations
import matplotlib.pyplot as plt

import numpy as np # for using np arrays

# for bulding and running deep learning model
import tensorflow as tf
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import concatenate
from tensorflow.keras.losses import binary_crossentropy
from sklearn.model_selection import train_test_split

# %%
'''2 - Helper Functions for Data Processing'''

## 2.1 - Load Data
###* the masked images are stored as png, unmasked (original) as jpg
###* the names of these 2 are same so for getting the right sample we can just sort the 2 lists

def LoadData (path1, path2):
    """
    Looks for relevant filenames in the shared path
    Returns 2 lists for original and masked files respectively

    """
    # Read the images folder like a list
    image_dataset = os.listdir(path1)
    mask_dataset = os.listdir(path2)

    # Make a list for images and masks filenames
    orig_img = []
    mask_img = []
    for file in image_dataset:
        orig_img.append(file)
    for file in mask_dataset:
        mask_img.append(file)

    # Sort the lists to get both of them in same order (the dataset has exactly the same name for images and corresponding masks)
    orig_img.sort()
    mask_img.sort()

    return orig_img, mask_img

## 2.2 - Pre-Process Data

def PreprocessData(img, mask, target_shape_img, target_shape_mask, path1, path2):
    """
    Processes the images and mask present in the shared list and path
    Returns a NumPy dataset with images as 3-D arrays of desired size
    Please note the masks in this dataset have only one channel
    """
    # Pull the relevant dimensions for image and mask
    m = len(img)                     # number of images
    i_h, i_w, i_c = target_shape_img   # pull height, width, and channels of image
    m_h, m_w, m_c = target_shape_mask  # pull height, width, and channels of mask

    # Define X and Y as number of images along with shape of one image
    X = np.zeros((m, i_h, i_w, i_c), dtype = np.float32)
    y = np.zeros((m, m_h, m_w, m_c), dtype = np.int32)

    # Resize images and masks
    for file in img:
        # convert image into an array of desired shape (3 channels)
        index = img.index(file)
        path = os.path.join(path1, file)
        single_img = Image.open(path).convert('RGB')
        single_img = single_img.resize((i_h, i_w))
        single_img = np.reshape(single_img, (i_h, i_w, i_c))
        single_img = single_img / 256
        X[index] = single_img
        # print(index)

        # convert mask into an array of desired shape (1 channel)
        single_mask_ind = mask[index]
        
        # path = os.path.join(path2, single_mask_ind)
        # single_mask = Image.open(path).convert('RGB')
        # single_mask = single_mask.resize((m_h, m_w))
        # # single_mask_array = np.array(single_mask)  # Convert to NumPy array
        # # print(f"Before reshaping: {single_mask_array.shape}")
        # single_mask = np.reshape(single_mask, (m_h, m_w, m_c))  # Reshape to (height, width, 1)
        # single_mask = (single_mask / 256) - 1  # Normalize and ensure classes #s start from 0
        # y[index] = single_mask
        print(single_mask_ind)
    print(i_h, i_w, i_c)
    print("\n")
    print(m_h, m_w, m_c)
    return X

# %%
'''3 - Constructing the U-Net Architecture'''

## 3.1 - U-Net Encoder Block

def EncoderMiniBlock(inputs, n_filters = 32, dropout_prob = 0.3, max_pooling = True):
    """
    This block uses multiple convolution layers, max pool, relu activation to create an architecture for learning.
    Dropout can be added for regularization to prevent overfitting.
    The block returns the activation values for next layer along with a skip connection which will be used in the decoder
    """
    # Add 2 Conv Layers with relu activation and HeNormal initialization using TensorFlow
    # Proper initialization prevents from the problem of exploding and vanishing gradients
    # 'Same' padding will pad the input to conv layer such that the output has the same height and width (hence, is not reduced in size)
    conv = Conv2D(n_filters,
                  3,   # Kernel size
                  activation = 'relu',
                  padding = 'same',
                  kernel_initializer = 'HeNormal')(inputs)
    conv = Conv2D(n_filters,
                  3,   # Kernel size
                  activation = 'relu',
                  padding = 'same',
                  kernel_initializer = 'HeNormal')(conv)

    # Batch Normalization will normalize the output of the last layer based on the batch's mean and standard deviation
    conv = BatchNormalization()(conv, training = False)

    # In case of overfitting, dropout will regularize the loss and gradient computation to shrink the influence of weights on output
    if dropout_prob > 0:
        conv = tf.keras.layers.Dropout(dropout_prob)(conv)

    # Pooling reduces the size of the image while keeping the number of channels same
    # Pooling has been kept as optional as the last encoder layer does not use pooling (hence, makes the encoder block flexible to use)
    # Below, Max pooling considers the maximum of the input slice for output computation and uses stride of 2 to traverse across input image
    if max_pooling:
        next_layer = tf.keras.layers.MaxPooling2D(pool_size = (2, 2))(conv)
    else:
        next_layer = conv

    # skip connection (without max pooling) will be input to the decoder layer to prevent information loss during transpose convolutions
    skip_connection = conv

    return next_layer, skip_connection

## 3.2 - U-Net Decoder Block

def DecoderMiniBlock(prev_layer_input, skip_layer_input, n_filters = 32):
    """
    Decoder Block first uses transpose convolution to upscale the image to a bigger size and then,
    merges the result with skip layer results from encoder block
    Adding 2 convolutions with 'same' padding helps further increase the depth of the network for better predictions
    The function returns the decoded layer output
    """
    # Start with a transpose convolution layer to first increase the size of the image
    up = Conv2DTranspose(
                 n_filters,
                 (3, 3),    # Kernel size
                 strides=(2, 2),
                 padding = 'same')(prev_layer_input)

    # Merge the skip connection from previous block to prevent information loss
    merge = concatenate([up, skip_layer_input], axis = 3)

    # Add 2 Conv Layers with relu activation and HeNormal initialization for further processing
    # The parameters for the function are similar to encoder
    conv = Conv2D(n_filters,
                 3,     # Kernel size
                 activation = 'relu',
                 padding = 'same',
                 kernel_initializer = 'HeNormal')(merge)
    conv = Conv2D(n_filters,
                 3,   # Kernel size
                 activation = 'relu',
                 padding = 'same',
                 kernel_initializer = 'HeNormal')(conv)
    return conv


## 3.3 - Compile U-Net Blocks

def UNetCompiled(input_size = (128, 128, 3), n_filters = 32, n_classes = 3):
    """
    Combine both encoder and decoder blocks according to the U-Net research paper
    Return the model as output
    """
    # Input size represent the size of 1 image (the size used for pre-processing)
    inputs = Input(input_size)

    # Encoder includes multiple convolutional mini blocks with different maxpooling, dropout and filter parameters
    # Observe that the filters are increasing as we go deeper into the network which will increasse the # channels of the image
    cblock1 = EncoderMiniBlock(inputs, n_filters, dropout_prob = 0, max_pooling = True)
    cblock2 = EncoderMiniBlock(cblock1[0], n_filters * 2, dropout_prob = 0, max_pooling = True)
    cblock3 = EncoderMiniBlock(cblock2[0], n_filters * 4, dropout_prob = 0, max_pooling = True)
    cblock4 = EncoderMiniBlock(cblock3[0], n_filters * 8, dropout_prob = 0.3, max_pooling = True)
    cblock5 = EncoderMiniBlock(cblock4[0], n_filters * 16, dropout_prob = 0.3, max_pooling = False)

    # Decoder includes multiple mini blocks with decreasing number of filters
    # Observe the skip connections from the encoder are given as input to the decoder
    # Recall the 2nd output of encoder block was skip connection, hence cblockn[1] is used
    ublock6 = DecoderMiniBlock(cblock5[0], cblock4[1],  n_filters * 8)
    ublock7 = DecoderMiniBlock(ublock6, cblock3[1],  n_filters * 4)
    ublock8 = DecoderMiniBlock(ublock7, cblock2[1],  n_filters * 2)
    ublock9 = DecoderMiniBlock(ublock8, cblock1[1],  n_filters)

    # Complete the model with 1 3x3 convolution layer (Same as the prev Conv Layers)
    # Followed by a 1x1 Conv layer to get the image to the desired size.
    # Observe the number of channels will be equal to number of output classes
    conv9 = Conv2D(n_filters,
                 3,
                 activation = 'relu',
                 padding = 'same',
                 kernel_initializer = 'he_normal')(ublock9)

    conv10 = Conv2D(n_classes, 1, padding = 'same')(conv9)

    # Define the model
    model = tf.keras.Model(inputs = inputs, outputs = conv10)

    return model

# %%
path2 = r"C:\Users\Soumil\Downloads\Auto-PCOS Challenge\PCOSGen-train-test-split\train\image3797.jpg"
img = Image.open(path2)

# Get the dimensions (width, height) of the image
img_size = img.size
print("Image Size:", img_size)
# Out:
# Image Size: (250, 221)

# %%
'''4 - Executing above Functions to Train the Model'''

## 4.1 - Load and View Data

""" Load Train Set and view some examples """
# Call the apt function
path1 = r"C:\Users\Soumil\Downloads\Auto-PCOS Challenge\PCOSGen-train-test-split\train"
path2 = r"C:\Users\Soumil\Downloads\Auto-PCOS Challenge\PCOSGen-train-test-split\train-masked"
img, mask = LoadData (path1, path2)

# View an example of image and corresponding mask
show_images = 1
for i in range(show_images):
    img_view = imageio.imread(os.path.join(path1, img[i]))

    mask_view = imageio.imread(os.path.join(path2, mask[i]))

    print(img_view.shape)
    print(mask_view.shape)
    fig, arr = plt.subplots(1, 2, figsize = (15, 15))
    arr[0].imshow(img_view)
    arr[0].set_title('Image '+ str(i))
    arr[1].imshow(mask_view)
    arr[1].set_title('Masked Image '+ str(i))

## 4.2 - Process Data

# Define the desired shape
target_shape_img = [128, 128, 3]
target_shape_mask = [128, 128, 1]

# Process data using apt helper function
X= PreprocessData(img, mask, target_shape_img, target_shape_mask, path1, path2)

# QC the shape of output and classes in output dataset
print("X Shape:", X.shape)
# print("Y shape:", y.shape)
# There are 3 classes : background, pet, outline
# print(np.unique(y))

# # Visualize the output
# image_index = 0
# fig, arr = plt.subplots(1, 2, figsize = (15, 15))
# arr[0].imshow(X[image_index])
# arr[0].set_title('Processed Image')
# arr[1].imshow(y[image_index, :, :, 0])
# arr[1].set_title('Processed Masked Image ')

# ## 4.3 - Split Train and Test Set"""

# # Use scikit-learn's function to split the dataset
# # Here, I have used 20% data as test/valid set
# X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size = 0.2, random_state = 123)
# summary

# ## 4.4 - Build U-Net Architecture

# # Call the helper function for defining the layers for the model, given the input image size
# unet = UNetCompiled(input_size = (128, 128, 3), n_filters = 32, n_classes = 3)

# # Check the summary to better interpret how the output dimensions change in each layer
# unet.summary()
# ## 4.5 - Compile and Run Model

# # There are multiple optimizers, loss functions and metrics that can be used to compile multi-class segmentation models
# # Ideally, try different options to get the best accuracy
# unet.compile(optimizer = tf.keras.optimizers.Adam(),
#             loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
#             metrics = ['accuracy'])

# # Run the model in a mini-batch fashion and compute the progress for each epoch
# results = unet.fit(X_train, y_train, batch_size = 32, epochs = 20, validation_data = (X_valid, y_valid))
# Out:
# (300, 300, 3)
# (300, 300, 3)
# masked_100image13.jpg
# masked_100image65.jpg
# masked_100image71.jpg
# masked_100image83.jpg
# masked_100image87.jpg
# masked_100image94.jpg
# masked_1019image14.jpg
# masked_101image14.jpg
# masked_101image31.jpg
# masked_102image93.jpg
# masked_103image0064.jpg
# masked_103image1.jpg
# masked_104image0086.jpg
# masked_104image104.jpg
# masked_104image83.jpg
# masked_105image100.jpg
# masked_106image103.jpg
# masked_106image7.jpg
# masked_107image11.jpg
# masked_107image34.jpg
# masked_107image90.jpg
# masked_108image0081.jpg
# masked_109image0071.jpg
# masked_109image0089.jpg
# masked_109image78.jpg
# masked_10image0017.jpg
# masked_10image17.jpg
# masked_10image41.jpg
# masked_10image65.jpg
# masked_110image0083.jpg
# masked_110image82.jpg
# masked_1112image12.jpg
# masked_111image43.jpg
# masked_111image9.jpg
# masked_112image12.jpg
# masked_112image88.jpg
# masked_112image91.jpg
# masked_113image0112.jpg
# masked_113image0114.jpg
# masked_114image74.jpg
# masked_115image72.jpg
# masked_116image0104.jpg
# masked_116image29.jpg
# masked_116image81.jpg
# masked_117image33.jpg
# masked_117image39.jpg
# masked_1180image18.jpg
# masked_118image1.jpg
# masked_118image62.jpg
# masked_119image0120.jpg
# masked_11image49.jpg
# masked_1209image17.jpg
# masked_120image0105.jpg
# masked_121image51.jpg
# masked_122image10.jpg
# masked_122image14.jpg
# masked_123image2.jpg
# masked_124image21.jpg
# masked_124image42.jpg
# masked_124image76.jpg
# masked_125image0.jpg
# masked_127image0115.jpg
# masked_127image57.jpg
# masked_128image46.jpg
# masked_12image0000.jpg
# masked_12image19.jpg
# masked_12image51.jpg
# masked_12image63.jpg
# masked_12image72.jpg
# masked_130image40.jpg
# masked_132image0110.jpg
# masked_132image4.jpg
# masked_134image0111.jpg
# masked_1394image4.jpg
# masked_139image15.jpg
# masked_13image0020.jpg
# masked_13image31.jpg
# masked_13image56.jpg
# masked_13image67.jpg
# masked_140image0108.jpg
# masked_140image0122.jpg
# masked_140image59.jpg
# masked_141image0125.jpg
# masked_143image0124.jpg
# masked_1456image5.jpg
# masked_145image15.jpg
# masked_145image20.jpg
# masked_146image10.jpg
# masked_146image22.jpg
# masked_146image26.jpg
# masked_146image57.jpg
# masked_146image63.jpg
# masked_146image73.jpg
# masked_146image9.jpg
# masked_148image34.jpg
# masked_148image64.jpg
# masked_149image12.jpg
# masked_149image28.jpg
# masked_150image17.jpg
# masked_150image51.jpg
# masked_151image36.jpg
# masked_151image55.jpg
# masked_153image45.jpg
# masked_154image0123.jpg
# masked_154image2.jpg
# masked_154image24.jpg
# masked_154image54.jpg
# masked_154image6.jpg
# masked_154image86.jpg
# masked_156image84.jpg
# masked_157image49.jpg
# masked_158image22.jpg
# masked_158image48.jpg
# masked_15image0033.jpg
# masked_15image12.jpg
# masked_15image15.jpg
# masked_15image46.jpg
# masked_160image8.jpg
# masked_161image8.jpg
# masked_162image21.jpg
# masked_162image41.jpg
# masked_163image26.jpg
# masked_163image42.jpg
# masked_164image27.jpg
# masked_165image18.jpg
# masked_167image14.jpg
# masked_168image43.jpg
# masked_168image44.jpg
# masked_16image27.jpg
# masked_16image34.jpg
# masked_16image48.jpg
# masked_16image53.jpg
# masked_16image55.jpg
# masked_170image37.jpg
# masked_170image94.jpg
# masked_171image29.jpg
# masked_171image47.jpg
# masked_171image9.jpg
# masked_173image52.jpg
# masked_173image71.jpg
# masked_174image13.jpg
# masked_174image58.jpg
# masked_176image15.jpg
# masked_1779image22.jpg
# masked_177image38.jpg
# masked_177image99.jpg
# masked_179image52.jpg
# masked_17image45.jpg
# masked_180image10.jpg
# masked_180image44.jpg
# masked_180image49.jpg
# masked_180image56.jpg
# masked_182image75.jpg
# masked_183image40.jpg
# masked_184image16.jpg
# masked_184image98.jpg
# masked_185image92.jpg
# masked_186image1.jpg
# masked_187image41.jpg
# masked_187image87.jpg
# masked_188image5.jpg
# masked_189image13.jpg
# masked_189image46.jpg
# masked_189image53.jpg
# masked_189image80.jpg
# masked_189image96.jpg
# masked_18image4.jpg
# masked_18image47.jpg
# masked_190image12.jpg
# masked_190image19.jpg
# masked_190image35.jpg
# masked_190image4.jpg
# masked_190image60.jpg
# masked_191image0.jpg
# masked_192image7.jpg
# masked_193image31.jpg
# masked_195image30.jpg
# masked_195image33.jpg
# masked_195image45.jpg
# masked_195image79.jpg
# masked_198image7.jpg
# masked_19image36.jpg
# masked_1image40.jpg
# masked_200image11.jpg
# masked_200image20.jpg
# masked_2024image15.jpg
# masked_202image3.jpg
# masked_204image23.jpg
# masked_205image36.jpg
# masked_205image48.jpg
# masked_206image102.jpg
# masked_206image6.jpg
# masked_207image56.jpg
# masked_208image47.jpg
# masked_20image0037.jpg
# masked_20image24.jpg
# masked_20image29.jpg
# masked_210image25.jpg
# masked_210image89.jpg
# masked_212image10.jpg
# masked_213image15.jpg
# masked_217image26.jpg
# masked_217image4.jpg
# masked_219image12.jpg
# masked_21image0014.jpg
# masked_21image0035.jpg
# masked_220image19.jpg
# masked_22image68.jpg
# masked_22image73.jpg
# masked_231image27.jpg
# masked_231image30.jpg
# masked_232image1.jpg
# masked_233image2.jpg
# masked_234image21.jpg
# masked_235image25.jpg
# masked_236image9.jpg
# masked_237image0.jpg
# masked_237image18.jpg
# masked_237image22.jpg
# masked_239image1.jpg
# masked_23image0030.jpg
# masked_23image0038.jpg
# masked_23image2.jpg
# masked_23image60.jpg
# masked_23image61.jpg
# masked_241image13.jpg
# masked_241image8.jpg
# masked_2481image8.jpg
# masked_248image11.jpg
# masked_248image23.jpg
# masked_24image0045.jpg
# masked_24image11.jpg
# masked_24image35.jpg
# masked_24image4.jpg
# masked_24image44.jpg
# masked_24image9.jpg
# masked_255image31.jpg
# masked_256image24.jpg
# masked_25image0002.jpg
# masked_25image0024.jpg
# masked_25image62.jpg
# masked_25image7.jpg
# masked_260image33.jpg
# masked_2634image16.jpg
# masked_270image12.jpg
# masked_276image8.jpg
# masked_27image0026.jpg
# masked_27image13.jpg
# masked_27image30.jpg
# masked_27image52.jpg
# masked_27image64.jpg
# masked_2818image10.jpg
# masked_286image4.jpg
# masked_28image0022.jpg
# masked_28image33.jpg
# masked_28image5.jpg
# masked_28image6.jpg
# masked_290image20.jpg
# masked_290image29.jpg
# masked_292image0.jpg
# masked_296image16.jpg
# masked_297image28.jpg
# masked_2image3.jpg
# masked_2image37.jpg
# masked_2image43.jpg
# masked_2image50.jpg
# masked_3003image20.jpg
# masked_304image9.jpg
# masked_308image32.jpg
# masked_30image0007.jpg
# masked_30image74.jpg
# masked_310image7.jpg
# masked_32image0025.jpg
# masked_3309image24.jpg
# masked_336image23.jpg
# masked_33image0049.jpg
# masked_35image0016.jpg
# masked_36image0008.jpg
# masked_36image0040.jpg
# masked_38image0005.jpg
# masked_3image0027.jpg
# masked_3image8.jpg
# masked_40image0021.jpg
# masked_418image21.jpg
# masked_41image0006.jpg
# masked_41image0010.jpg
# masked_41image0028.jpg
# masked_44image0004.jpg
# masked_45image0029.jpg
# masked_45image0051.jpg
# masked_46image0031.jpg
# masked_46image0044.jpg
# masked_46image10.jpg
# masked_47image0003.jpg
# masked_47image0046.jpg
# masked_48image0.jpg
# masked_49image0009.jpg
# masked_49image0023.jpg
# masked_49image0041.jpg
# masked_4image7.jpg
# masked_4image70.jpg
# masked_501image3.jpg
# masked_501image31.jpg
# masked_50image8.jpg
# masked_516image16.jpg
# masked_518image25.jpg
# masked_519image24.jpg
# masked_51image0034.jpg
# masked_520image0.jpg
# masked_523image18.jpg
# masked_529image2.jpg
# masked_529image9.jpg
# masked_52image0001.jpg
# masked_532image27.jpg
# masked_535image32.jpg
# masked_536image28.jpg
# masked_539image6.jpg
# masked_53image0011.jpg
# masked_53image0012.jpg
# masked_543image12.jpg
# masked_549image29.jpg
# masked_54image0079.jpg
# masked_54image30.jpg
# masked_553image22.jpg
# masked_55image24.jpg
# masked_55image7.jpg
# masked_560image1.jpg
# masked_563image20.jpg
# masked_564image8.jpg
# masked_56image0068.jpg
# masked_571image14.jpg
# masked_571image21.jpg
# masked_577image7.jpg
# masked_578image26.jpg
# masked_57image38.jpg
# masked_584image17.jpg
# masked_585image4.jpg
# masked_58image31.jpg
# masked_595image11.jpg
# masked_595image19.jpg
# masked_59image21.jpg
# masked_5image28.jpg
# masked_5image3.jpg
# masked_5image42.jpg
# masked_60image0.jpg
# masked_60image0063.jpg
# masked_60image1.jpg
# masked_62image0077.jpg
# masked_62image9.jpg
# masked_63image0070.jpg
# masked_63image0103.jpg
# masked_64image0054.jpg
# masked_64image27.jpg
# masked_64image8.jpg
# masked_658image7.jpg
# masked_65image0094.jpg
# masked_66image19.jpg
# masked_67image0080.jpg
# masked_69image6.jpg
# masked_6image0042.jpg
# masked_6image21.jpg
# masked_70image0095.jpg
# masked_71image11.jpg
# masked_71image36.jpg
# masked_72image0096.jpg
# masked_73image0092.jpg
# masked_74image2.jpg
# masked_75image0057.jpg
# masked_75image0097.jpg
# masked_77image0076.jpg
# masked_78image39.jpg
# masked_79image0065.jpg
# masked_79image3.jpg
# masked_7image14.jpg
# masked_814image1.jpg
# masked_81image10.jpg
# masked_83image0073.jpg
# masked_83image26.jpg
# masked_83image37.jpg
# masked_84image0085.jpg
# masked_84image20.jpg
# masked_85image5.jpg
# masked_86image0099.jpg
# masked_86image1.jpg
# masked_86image12.jpg
# masked_87image8.jpg
# masked_88image0082.jpg
# masked_88image11.jpg
# masked_88image18.jpg
# masked_89image0101.jpg
# masked_89image14.jpg
# masked_89image41.jpg
# masked_89image5.jpg
# masked_89image6.jpg
# masked_8image16.jpg
# masked_8image54.jpg
# masked_90image11.jpg
# masked_90image15.jpg
# masked_90image36.jpg
# masked_90image46.jpg
# masked_90image66.jpg
# masked_90image76.jpg
# masked_90image9.jpg
# masked_91image0059.jpg
# masked_91image12.jpg
# masked_91image28.jpg
# masked_91image30.jpg
# masked_91image4.jpg
# masked_91image7.jpg
# masked_91image74.jpg
# masked_91image78.jpg
# masked_91image91.jpg
# masked_92image0087.jpg
# masked_92image1.jpg
# masked_92image14.jpg
# masked_92image22.jpg
# masked_92image25.jpg
# masked_92image26.jpg
# masked_92image29.jpg
# masked_92image53.jpg
# masked_92image80.jpg
# masked_933image13.jpg
# masked_93image19.jpg
# masked_93image3.jpg
# masked_93image33.jpg
# masked_93image41.jpg
# masked_93image50.jpg
# masked_93image62.jpg
# masked_93image79.jpg
# masked_94image10.jpg
# masked_94image17.jpg
# masked_94image21.jpg
# masked_94image24.jpg
# masked_94image57.jpg
# masked_94image59.jpg
# masked_94image75.jpg
# masked_94image88.jpg
# masked_94image90.jpg
# masked_95image0061.jpg
# masked_95image23.jpg
# masked_95image4.jpg
# masked_95image47.jpg
# masked_95image51.jpg
# masked_95image93.jpg
# masked_96image0066.jpg
# masked_96image23.jpg
# masked_96image45.jpg
# masked_96image56.jpg
# masked_96image60.jpg
# masked_96image69.jpg
# masked_96image70.jpg
# masked_96image86.jpg
# masked_96image9.jpg
# masked_96image95.jpg
# masked_97image0067.jpg
# masked_97image16.jpg
# masked_97image17.jpg
# masked_97image34.jpg
# masked_97image5.jpg
# masked_97image54.jpg
# masked_97image55.jpg
# masked_98image16.jpg
# masked_98image48.jpg
# masked_98image49.jpg
# masked_99image0088.jpg
# masked_99image18.jpg
# masked_99image20.jpg
# masked_99image28.jpg
# masked_99image32.jpg
# masked_99image34.jpg
# masked_99image37.jpg
# masked_99image40.jpg
# masked_99image44.jpg
# masked_99image72.jpg
# masked_99image84.jpg
# masked_9image0043.jpg
# masked_9image20.jpg
# masked_9image25.jpg
# masked_9image32.jpg
# masked_9image59.jpg
# masked_frame0-01-00.03.jpg
# masked_image0006.jpg
# masked_image0008.jpg
# masked_image0012.jpg
# masked_image0013.jpg
# masked_image0014.jpg
# masked_image0050.jpg
# masked_image0052.jpg
# masked_image0054.jpg
# masked_image0055.jpg
# masked_image0056.jpg
# masked_image0057.jpg
# masked_image0058.jpg
# masked_image0059.jpg
# masked_image0061.jpg
# masked_image0065.jpg
# masked_image0066.jpg
# masked_image0068.jpg
# masked_image0069.jpg
# masked_image0070.jpg
# masked_image0071.jpg
# masked_image0072.jpg
# masked_image0073.jpg
# masked_image0074.jpg
# masked_image0075.jpg
# masked_image0076.jpg
# masked_image0077.jpg
# masked_image0078.jpg
# masked_image0083.jpg
# masked_image0084.jpg
# masked_image0085.jpg
# masked_image0086.jpg
# masked_image0088.jpg
# masked_image0089.jpg
# masked_image0090.jpg
# masked_image0091.jpg
# masked_image0092.jpg
# masked_image0093.jpg
# masked_image0094.jpg
# masked_image0095.jpg
# masked_image0098.jpg
# masked_image0100.jpg
# masked_image0101.jpg
# masked_image0102.jpg
# masked_image0104.jpg
# masked_image0105.jpg
# masked_image0106.jpg
# masked_image0107.jpg
# masked_image0108.jpg
# masked_image0111.jpg
# masked_image0112.jpg
# masked_image0113.jpg
# masked_image0115.jpg
# masked_image0116.jpg
# masked_image0119.jpg
# masked_image0120.jpg
# masked_image0121.jpg
# masked_image0122.jpg
# masked_image0124.jpg
# masked_image0199.jpg
# masked_image0200.jpg
# masked_image0201.jpg
# masked_image0202.jpg
# masked_image0203.jpg
# masked_image0204.jpg
# masked_image0205.jpg
# masked_image0206.jpg
# masked_image0210.jpg
# masked_image0211.jpg
# masked_image0212.jpg
# masked_image0213.jpg
# masked_image0214.jpg
# masked_image0215.jpg
# masked_image0216.jpg
# masked_image0217.jpg
# masked_image0218.jpg
# masked_image0219.jpg
# masked_image0220.jpg
# masked_image0221.jpg
# masked_image0222.jpg
# masked_image0223.jpg
# masked_image0224.jpg
# masked_image0225.jpg
# masked_image0226.jpg
# masked_image0229.jpg
# masked_image0231.jpg
# masked_image0232.jpg
# masked_image0234.jpg
# masked_image0235.jpg
# masked_image0236.jpg
# masked_image0237.jpg
# masked_image0238.jpg
# masked_image0239.jpg
# masked_image0240.jpg
# masked_image0244.jpg
# masked_image0246.jpg
# masked_image0247.jpg
# masked_image0249.jpg
# masked_image0250.jpg
# masked_image0251.jpg
# masked_image0252.jpg
# masked_image0253.jpg
# masked_image0254.jpg
# masked_image0255.jpg
# masked_image0256.jpg
# masked_image0257.jpg
# masked_image0258.jpg
# masked_image0259.jpg
# masked_image0260.jpg
# masked_image0262.jpg
# masked_image0263.jpg
# masked_image0264.jpg
# masked_image0266.jpg
# masked_image0267.jpg
# masked_image0268.jpg
# masked_image0270.jpg
# masked_image0271.jpg
# masked_image0272.jpg
# masked_image0273.jpg
# masked_image0275.jpg
# masked_image0276.jpg
# masked_image0277.jpg
# masked_image0278.jpg
# masked_image0279.jpg
# masked_image0280.jpg
# masked_image0281.jpg
# masked_image0282.jpg
# masked_image0283.jpg
# masked_image0284.jpg
# masked_image0285.jpg
# masked_image0286.jpg
# masked_image0287.jpg
# masked_image0288.jpg
# masked_image0289.jpg
# masked_image0290.jpg
# masked_image0291.jpg
# masked_image0292.jpg
# masked_image0294.jpg
# masked_image0295.jpg
# masked_image0297.jpg
# masked_image0298.jpg
# masked_image0299.jpg
# masked_image0300.jpg
# masked_image0302.jpg
# masked_image0304.jpg
# masked_image0306.jpg
# masked_image0307.jpg
# masked_image0311.jpg
# masked_image0312.jpg
# masked_image0314.jpg
# masked_image0315.jpg
# masked_image0316.jpg
# masked_image0317.jpg
# masked_image0318.jpg
# masked_image0319.jpg
# masked_image0320.jpg
# masked_image0321.jpg
# masked_image0322.jpg
# masked_image0323.jpg
# masked_image0324.jpg
# masked_image0325.jpg
# masked_image0327.jpg
# masked_image0328.jpg
# masked_image0329.jpg
# masked_image0330.jpg
# masked_image0333.jpg
# masked_image0334.jpg
# masked_image0337.jpg
# masked_image0338.jpg
# masked_image0341.jpg
# masked_image0342.jpg
# masked_image0343.jpg
# masked_image0346.jpg
# masked_image0347.jpg
# masked_image0348.jpg
# masked_image0350.jpg
# masked_image0351.jpg
# masked_image0354.jpg
# masked_image0355.jpg
# masked_image0356.jpg
# masked_image0357.jpg
# masked_image0358.jpg
# masked_image0359.jpg
# masked_image0360.jpg
# masked_image0361.jpg
# masked_image0367.jpg
# masked_image0368.jpg
# masked_image0375.jpg
# masked_image0376.jpg
# masked_image0377.jpg
# masked_image0378.jpg
# masked_image0381.jpg
# masked_image0382.jpg
# masked_image0383.jpg
# masked_image0384.jpg
# masked_image0387.jpg
# masked_image0390.jpg
# masked_image0391.jpg
# masked_image0392.jpg
# masked_image0394.jpg
# masked_image0395.jpg
# masked_image0396.jpg
# masked_image0397.jpg
# masked_image0398.jpg
# masked_image0399.jpg
# masked_image0400.jpg
# masked_image0401.jpg
# masked_image0402.jpg
# masked_image0404.jpg
# masked_image0406.jpg
# masked_image0407.jpg
# masked_image0408.jpg
# masked_image0409.jpg
# masked_image0410.jpg
# masked_image0411.jpg
# masked_image0412.jpg
# masked_image0413.jpg
# masked_image0414.jpg
# masked_image0415.jpg
# masked_image0418.jpg
# masked_image0419.jpg
# masked_image0420.jpg
# masked_image0421.jpg
# masked_image0422.jpg
# masked_image0423.jpg
# masked_image0426.jpg
# masked_image0427.jpg
# masked_image0428.jpg
# masked_image0429.jpg
# masked_image0431.jpg
# masked_image0432.jpg
# masked_image0433.jpg
# masked_image0434.jpg
# masked_image0435.jpg
# masked_image0436.jpg
# masked_image0437.jpg
# masked_image0438.jpg
# masked_image0440.jpg
# masked_image0441.jpg
# masked_image0442.jpg
# masked_image0443.jpg
# masked_image0444.jpg
# masked_image0445.jpg
# masked_image0446.jpg
# masked_image0449.jpg
# masked_image0450.jpg
# masked_image0451.jpg
# masked_image0453.jpg
# masked_image0457.jpg
# masked_image0460.jpg
# masked_image0465.jpg
# masked_image0466.jpg
# masked_image0467.jpg
# masked_image0468.jpg
# masked_image0469.jpg
# masked_image0471.jpg
# masked_image0472.jpg
# masked_image0473.jpg
# masked_image0474.jpg
# masked_image0475.jpg
# masked_image0476.jpg
# masked_image0477.jpg
# masked_image0478.jpg
# masked_image0479.jpg
# masked_image0480.jpg
# masked_image0482.jpg
# masked_image0484.jpg
# masked_image0485.jpg
# masked_image0486.jpg
# masked_image0487.jpg
# masked_image0488.jpg
# masked_image0490.jpg
# masked_image0491.jpg
# masked_image0493.jpg
# masked_image0494.jpg
# masked_image0495.jpg
# masked_image0496.jpg
# masked_image0497.jpg
# masked_image0498.jpg
# masked_image0499.jpg
# masked_image0500.jpg
# masked_image0501.jpg
# masked_image0502.jpg
# masked_image0503.jpg
# masked_image0505.jpg
# masked_image0506.jpg
# masked_image0507.jpg
# masked_image0508.jpg
# masked_image0509.jpg
# masked_image0510.jpg
# masked_image0511.jpg
# masked_image0512.jpg
# masked_image0513.jpg
# masked_image0514.jpg
# masked_image0515.jpg
# masked_image0516.jpg
# masked_image0518.jpg
# masked_image0519.jpg
# masked_image0520.jpg
# masked_image0522.jpg
# masked_image0523.jpg
# masked_image0524.jpg
# masked_image0525.jpg
# masked_image0526.jpg
# masked_image0527.jpg
# masked_image0529.jpg
# masked_image0530.jpg
# masked_image0531.jpg
# masked_image0532.jpg
# masked_image0533.jpg
# masked_image0535.jpg
# masked_image0536.jpg
# masked_image0537.jpg
# masked_image0539.jpg
# masked_image0540.jpg
# masked_image0541.jpg
# masked_image0542.jpg
# masked_image0543.jpg
# masked_image0544.jpg
# masked_image0545.jpg
# masked_image0546.jpg
# masked_image0547.jpg
# masked_image0548.jpg
# masked_image0549.jpg
# masked_image0550.jpg
# masked_image0553.jpg
# masked_image0554.jpg
# masked_image0555.jpg
# masked_image0558.jpg
# masked_image0559.jpg
# masked_image0563.jpg
# masked_image0565.jpg
# masked_image0566.jpg
# masked_image0567.jpg
# masked_image0568.jpg
# masked_image0570.jpg
# masked_image0571.jpg
# masked_image0572.jpg
# masked_image0573.jpg
# masked_image0574.jpg
# masked_image0575.jpg
# masked_image0576.jpg
# masked_image0577.jpg
# masked_image0579.jpg
# masked_image0581.jpg
# masked_image0582.jpg
# masked_image0583.jpg
# masked_image0585.jpg
# masked_image0586.jpg
# masked_image0587.jpg
# masked_image0589.jpg
# masked_image0591.jpg
# masked_image0592.jpg
# masked_image0594.jpg
# masked_image0595.jpg
# masked_image0596.jpg
# masked_image0597.jpg
# masked_image0599.jpg
# masked_image0600.jpg
# masked_image0601.jpg
# masked_image0603.jpg
# masked_image0604.jpg
# masked_image0605.jpg
# masked_image0607.jpg
# masked_image0608.jpg
# masked_image0610.jpg
# masked_image0611.jpg
# masked_image0613.jpg
# masked_image0615.jpg
# masked_image0616.jpg
# masked_image0617.jpg
# masked_image0618.jpg
# masked_image0619.jpg
# masked_image0620.jpg
# masked_image0621.jpg
# masked_image0622.jpg
# masked_image0623.jpg
# masked_image0624.jpg
# masked_image0625.jpg
# masked_image0626.jpg
# masked_image0627.jpg
# masked_image0628.jpg
# masked_image0629.jpg
# masked_image0630.jpg
# masked_image0631.jpg
# masked_image0632.jpg
# masked_image0633.jpg
# masked_image0634.jpg
# masked_image0635.jpg
# masked_image0636.jpg
# masked_image0637.jpg
# masked_image0639.jpg
# masked_image0641.jpg
# masked_image0642.jpg
# masked_image0643.jpg
# masked_image0646.jpg
# masked_image0647.jpg
# masked_image0648.jpg
# masked_image0649.jpg
# masked_image0650.jpg
# masked_image0651.jpg
# masked_image0652.jpg
# masked_image0653.jpg
# masked_image0654.jpg
# masked_image0655.jpg
# masked_image0656.jpg
# masked_image0657.jpg
# masked_image0658.jpg
# masked_image0659.jpg
# masked_image0660.jpg
# masked_image0662.jpg
# masked_image0664.jpg
# masked_image0665.jpg
# masked_image0666.jpg
# masked_image0667.jpg
# masked_image0668.jpg
# masked_image0669.jpg
# masked_image0670.jpg
# masked_image0671.jpg
# masked_image0674.jpg
# masked_image0675.jpg
# masked_image0676.jpg
# masked_image0680.jpg
# masked_image0681.jpg
# masked_image0683.jpg
# masked_image0686.jpg
# masked_image0687.jpg
# masked_image0688.jpg
# masked_image0689.jpg
# masked_image0691.jpg
# masked_image0692.jpg
# masked_image0694.jpg
# masked_image0696.jpg
# masked_image0697.jpg
# masked_image0698.jpg
# masked_image0699.jpg
# masked_image0700.jpg
# masked_image0702.jpg
# masked_image0703.jpg
# masked_image0704.jpg
# masked_image0705.jpg
# masked_image0706.jpg
# masked_image0707.jpg
# masked_image0708.jpg
# masked_image0710.jpg
# masked_image0711.jpg
# masked_image0712.jpg
# masked_image0713.jpg
# masked_image0715.jpg
# masked_image0716.jpg
# masked_image0717.jpg
# masked_image0718.jpg
# masked_image0721.jpg
# masked_image0722.jpg
# masked_image0723.jpg
# masked_image0724.jpg
# masked_image0725.jpg
# masked_image0726.jpg
# masked_image0729.jpg
# masked_image0730.jpg
# masked_image0731.jpg
# masked_image0732.jpg
# masked_image0733.jpg
# masked_image0735.jpg
# masked_image0737.jpg
# masked_image0738.jpg
# masked_image0739.jpg
# masked_image0740.jpg
# masked_image0742.jpg
# masked_image0743.jpg
# masked_image0744.jpg
# masked_image0746.jpg
# masked_image0747.jpg
# masked_image0749.jpg
# masked_image0750.jpg
# masked_image0751.jpg
# masked_image0753.jpg
# masked_image0754.jpg
# masked_image0755.jpg
# masked_image0756.jpg
# masked_image0757.jpg
# masked_image0758.jpg
# masked_image0759.jpg
# masked_image0764.jpg
# masked_image0766.jpg
# masked_image0769.jpg
# masked_image0770.jpg
# masked_image0771.jpg
# masked_image0772.jpg
# masked_image0773.jpg
# masked_image0774.jpg
# masked_image0775.jpg
# masked_image0776.jpg
# masked_image0777.jpg
# masked_image0778.jpg
# masked_image0780.jpg
# masked_image0781.jpg
# masked_image0783.jpg
# masked_image0784.jpg
# masked_image0785.jpg
# masked_image0786.jpg
# masked_image0787.jpg
# masked_image0788.jpg
# masked_image0789.jpg
# masked_image0790.jpg
# masked_image0791.jpg
# masked_image0792.jpg
# masked_image0794.jpg
# masked_image0795.jpg
# masked_image0796.jpg
# masked_image0797.jpg
# masked_image0798.jpg
# masked_image0799.jpg
# masked_image0800.jpg
# masked_image0801.jpg
# masked_image0803.jpg
# masked_image0805.jpg
# masked_image0806.jpg
# masked_image0807.jpg
# masked_image0808.jpg
# masked_image0809.jpg
# masked_image0810.jpg
# masked_image0811.jpg
# masked_image0812.jpg
# masked_image0813.jpg
# masked_image0814.jpg
# masked_image0815.jpg
# masked_image0816.jpg
# masked_image0819.jpg
# masked_image0821.jpg
# masked_image0822.jpg
# masked_image0823.jpg
# masked_image0826.jpg
# masked_image0829.jpg
# masked_image0830.jpg
# masked_image0831.jpg
# masked_image0832.jpg
# masked_image0834.jpg
# masked_image0835.jpg
# masked_image0836.jpg
# masked_image0838.jpg
# masked_image0839.jpg
# masked_image0840.jpg
# masked_image0841.jpg
# masked_image0842.jpg
# masked_image0844.jpg
# masked_image0845.jpg
# masked_image0848.jpg
# masked_image0849.jpg
# masked_image0851.jpg
# masked_image0853.jpg
# masked_image0854.jpg
# masked_image0855.jpg
# masked_image0856.jpg
# masked_image0857.jpg
# masked_image0858.jpg
# masked_image0859.jpg
# masked_image0861.jpg
# masked_image0862.jpg
# masked_image0864.jpg
# masked_image0867.jpg
# masked_image0869.jpg
# masked_image0870.jpg
# masked_image0871.jpg
# masked_image0872.jpg
# masked_image0873.jpg
# masked_image0874.jpg
# masked_image0875.jpg
# masked_image0877.jpg
# masked_image0879.jpg
# masked_image0880.jpg
# masked_image0881.jpg
# masked_image0882.jpg
# masked_image0883.jpg
# masked_image0886.jpg
# masked_image0887.jpg
# masked_image0888.jpg
# masked_image0889.jpg
# masked_image0890.jpg
# masked_image0892.jpg
# masked_image0893.jpg
# masked_image0895.jpg
# masked_image0896.jpg
# masked_image0897.jpg
# masked_image0898.jpg
# masked_image0899.jpg
# masked_image0900.jpg
# masked_image0903.jpg
# masked_image0904.jpg
# masked_image0906.jpg
# masked_image0907.jpg
# masked_image0908.jpg
# masked_image0909.jpg
# masked_image0912.jpg
# masked_image0913.jpg
# masked_image0914.jpg
# masked_image0915.jpg
# masked_image0916.jpg
# masked_image0917.jpg
# masked_image0919.jpg
# masked_image0921.jpg
# masked_image0922.jpg
# masked_image0927.jpg
# masked_image0928.jpg
# masked_image0929.jpg
# masked_image0930.jpg
# masked_image0931.jpg
# masked_image0932.jpg
# masked_image0934.jpg
# masked_image0937.jpg
# masked_image0938.jpg
# masked_image0939.jpg
# masked_image0940.jpg
# masked_image0941.jpg
# masked_image0942.jpg
# masked_image0944.jpg
# masked_image0946.jpg
# masked_image0948.jpg
# masked_image0949.jpg
# masked_image0950.jpg
# masked_image0951.jpg
# masked_image0952.jpg
# masked_image0953.jpg
# masked_image0954.jpg
# masked_image0955.jpg
# masked_image0956.jpg
# masked_image0958.jpg
# masked_image0962.jpg
# masked_image0963.jpg
# masked_image0964.jpg
# masked_image0965.jpg
# masked_image0966.jpg
# masked_image0967.jpg
# masked_image0969.jpg
# masked_image0970.jpg
# masked_image0971.jpg
# masked_image0973.jpg
# masked_image0975.jpg
# masked_image0976.jpg
# masked_image0977.jpg
# masked_image0978.jpg
# masked_image0979.jpg
# masked_image0981.jpg
# masked_image0983.jpg
# masked_image0985.jpg
# masked_image0987.jpg
# masked_image0988.jpg
# masked_image0989.jpg
# masked_image0992.jpg
# masked_image0993.jpg
# masked_image0994.jpg
# masked_image0995.jpg
# masked_image0996.jpg
# masked_image0997.jpg
# masked_image0998.jpg
# masked_image1000.jpg
# masked_image1001.jpg
# masked_image1002.jpg
# masked_image1003.jpg
# masked_image1004.jpg
# masked_image1006.jpg
# masked_image1007.jpg
# masked_image1009.jpg
# masked_image1010.jpg
# masked_image1011.jpg
# masked_image1013.jpg
# masked_image1015.jpg
# masked_image1016.jpg
# masked_image1017.jpg
# masked_image1018.jpg
# masked_image1020.jpg
# masked_image1023.jpg
# masked_image1026.jpg
# masked_image1027.jpg
# masked_image1028.jpg
# masked_image1029.jpg
# masked_image1030.jpg
# masked_image1031.jpg
# masked_image1032.jpg
# masked_image1033.jpg
# masked_image1035.jpg
# masked_image1036.jpg
# masked_image1037.jpg
# masked_image1038.jpg
# masked_image1039.jpg
# masked_image1040.jpg
# masked_image1042.jpg
# masked_image1045.jpg
# masked_image1046.jpg
# masked_image1048.jpg
# masked_image1049.jpg
# masked_image1050.jpg
# masked_image1051.jpg
# masked_image1052.jpg
# masked_image1054.jpg
# masked_image1055.jpg
# masked_image1056.jpg
# masked_image1059.jpg
# masked_image1060.jpg
# masked_image1061.jpg
# masked_image1062.jpg
# masked_image1064.jpg
# masked_image1066.jpg
# masked_image1067.jpg
# masked_image1068.jpg
# masked_image1069.jpg
# masked_image1070.jpg
# masked_image1071.jpg
# masked_image1072.jpg
# masked_image1073.jpg
# masked_image1074.jpg
# masked_image1075.jpg
# masked_image1077.jpg
# masked_image1079.jpg
# masked_image1080.jpg
# masked_image1081.jpg
# masked_image1082.jpg
# masked_image1083.jpg
# masked_image1085.jpg
# masked_image1086.jpg
# masked_image1088.jpg
# masked_image1089.jpg
# masked_image1090.jpg
# masked_image1091.jpg
# masked_image1092.jpg
# masked_image1093.jpg
# masked_image1094.jpg
# masked_image1095.jpg
# masked_image1097.jpg
# masked_image1098.jpg
# masked_image1099.jpg
# masked_image1100.jpg
# masked_image1101.jpg
# masked_image1105.jpg
# masked_image1107.jpg
# masked_image1108.jpg
# masked_image1109.jpg
# masked_image1110.jpg
# masked_image1111.jpg
# masked_image1112.jpg
# masked_image1113.jpg
# masked_image1114.jpg
# masked_image1115.jpg
# masked_image1116.jpg
# masked_image1117.jpg
# masked_image1118.jpg
# masked_image1119.jpg
# masked_image1120.jpg
# masked_image1122.jpg
# masked_image1123.jpg
# masked_image1126.jpg
# masked_image1127.jpg
# masked_image1128.jpg
# masked_image1129.jpg
# masked_image1132.jpg
# masked_image1135.jpg
# masked_image1136.jpg
# masked_image1137.jpg
# masked_image1139.jpg
# masked_image1140.jpg
# masked_image1141.jpg
# masked_image1142.jpg
# masked_image1143.jpg
# masked_image1144.jpg
# masked_image1145.jpg
# masked_image1146.jpg
# masked_image1147.jpg
# masked_image1149.jpg
# masked_image1150.jpg
# masked_image1151.jpg
# masked_image1152.jpg
# masked_image1154.jpg
# masked_image1155.jpg
# masked_image1156.jpg
# masked_image1157.jpg
# masked_image1158.jpg
# masked_image1159.jpg
# masked_image1161.jpg
# masked_image1162.jpg
# masked_image1165.jpg
# masked_image1166.jpg
# masked_image1167.jpg
# masked_image1169.jpg
# masked_image1170.jpg
# masked_image1172.jpg
# masked_image1173.jpg
# masked_image1174.jpg
# masked_image1177.jpg
# masked_image1178.jpg
# masked_image1179.jpg
# masked_image1180.jpg
# masked_image1181.jpg
# masked_image1182.jpg
# masked_image1183.jpg
# masked_image1185.jpg
# masked_image1188.jpg
# masked_image1189.jpg
# masked_image1191.jpg
# masked_image1193.jpg
# masked_image1194.jpg
# masked_image1195.jpg
# masked_image1196.jpg
# masked_image1197.jpg
# masked_image1198.jpg
# masked_image1199.jpg
# masked_image1200.jpg
# masked_image1220.jpg
# masked_image1221.jpg
# masked_image1224.jpg
# masked_image1240.jpg
# masked_image1242.jpg
# masked_image1244.jpg
# masked_image1250.jpg
# masked_image1267.jpg
# masked_image1275.jpg
# masked_image1276.jpg
# masked_image1277.jpg
# masked_image1278.jpg
# masked_image1279.jpg
# masked_image1280.jpg
# masked_image1281.jpg
# masked_image1283.jpg
# masked_image1286.jpg
# masked_image1292.jpg
# masked_image1297.jpg
# masked_image1378.jpg
# masked_image1379.jpg
# masked_image1380.jpg
# masked_image1381.jpg
# masked_image1383.jpg
# masked_image1384.jpg
# masked_image1386.jpg
# masked_image1395.jpg
# masked_image1397.jpg
# masked_image1398.jpg
# masked_image1399.jpg
# masked_image1400.jpg
# masked_image1403.jpg
# masked_image1404.jpg
# masked_image1405.jpg
# masked_image1413.jpg
# masked_image1419.jpg
# masked_image1464.jpg
# masked_image1465.jpg
# masked_image1466.jpg
# masked_image1467.jpg
# masked_image1468.jpg
# masked_image1469.jpg
# masked_image1470.jpg
# masked_image1471.jpg
# masked_image1472.jpg
# masked_image1473.jpg
# masked_image1474.jpg
# masked_image1490.jpg
# masked_image1491.jpg
# masked_image1559.jpg
# masked_image1560.jpg
# masked_image1562.jpg
# masked_image1584.jpg
# masked_image1603.jpg
# masked_image1606.jpg
# masked_image1607.jpg
# masked_image1629.jpg
# masked_image1630.jpg
# masked_image1632.jpg
# masked_image1633.jpg
# masked_image1635.jpg
# masked_image1636.jpg
# masked_image1637.jpg
# masked_image1638.jpg
# masked_image1641.jpg
# masked_image1643.jpg
# masked_image1646.jpg
# masked_image1648.jpg
# masked_image1649.jpg
# masked_image1650.jpg
# masked_image1651.jpg
# masked_image1652.jpg
# masked_image1654.jpg
# masked_image1655.jpg
# masked_image1656.jpg
# masked_image1659.jpg
# masked_image1661.jpg
# masked_image1666.jpg
# masked_image1667.jpg
# masked_image1668.jpg
# masked_image1669.jpg
# masked_image1672.jpg
# masked_image1675.jpg
# masked_image1676.jpg
# masked_image1677.jpg
# masked_image1680.jpg
# masked_image1681.jpg
# masked_image1683.jpg
# masked_image1684.jpg
# masked_image1685.jpg
# masked_image1686.jpg
# masked_image1687.jpg
# masked_image1688.jpg
# masked_image1690.jpg
# masked_image1691.jpg
# masked_image1694.jpg
# masked_image1695.jpg
# masked_image1696.jpg
# masked_image1705.jpg
# masked_image1706.jpg
# masked_image1708.jpg
# masked_image1709.jpg
# masked_image1710.jpg
# masked_image1712.jpg
# masked_image1713.jpg
# masked_image1715.jpg
# masked_image1744.jpg
# masked_image1745.jpg
# masked_image1747.jpg
# masked_image1748.jpg
# masked_image1758.jpg
# masked_image1760.jpg
# masked_image1764.jpg
# masked_image1765.jpg
# masked_image1766.jpg
# masked_image1767.jpg
# masked_image1768.jpg
# masked_image1779.jpg
# masked_image1782.jpg
# masked_image1790.jpg
# masked_image1791.jpg
# masked_image1793.jpg
# masked_image1794.jpg
# masked_image1800.jpg
# masked_image1801.jpg
# masked_image1802.jpg
# masked_image1803.jpg
# masked_image1810.jpg
# masked_image1812.jpg
# masked_image1813.jpg
# masked_image1814.jpg
# masked_image1815.jpg
# masked_image1818.jpg
# masked_image1819.jpg
# masked_image1820.jpg
# masked_image1821.jpg
# masked_image1822.jpg
# masked_image1823.jpg
# masked_image1824.jpg
# masked_image1825.jpg
# masked_image1827.jpg
# masked_image1828.jpg
# masked_image1830.jpg
# masked_image1833.jpg
# masked_image1834.jpg
# masked_image1835.jpg
# masked_image1838.jpg
# masked_image1839.jpg
# masked_image1840.jpg
# masked_image1849.jpg
# masked_image1850.jpg
# masked_image1851.jpg
# masked_image1853.jpg
# masked_image1854.jpg
# masked_image1855.jpg
# masked_image1858.jpg
# masked_image1860.jpg
# masked_image1861.jpg
# masked_image1862.jpg
# masked_image1863.jpg
# masked_image1864.jpg
# masked_image1865.jpg
# masked_image1867.jpg
# masked_image1868.jpg
# masked_image1869.jpg
# masked_image1872.jpg
# masked_image1873.jpg
# masked_image1874.jpg
# masked_image1875.jpg
# masked_image1876.jpg
# masked_image1877.jpg
# masked_image1879.jpg
# masked_image1880.jpg
# masked_image1881.jpg
# masked_image1882.jpg
# masked_image1890.jpg
# masked_image1891.jpg
# masked_image1907.jpg
# masked_image1911.jpg
# masked_image1912.jpg
# masked_image1913.jpg
# masked_image1914.jpg
# masked_image1917.jpg
# masked_image1918.jpg
# masked_image1933.jpg
# masked_image1934.jpg
# masked_image1935.jpg
# masked_image1936.jpg
# masked_image1937.jpg
# masked_image1938.jpg
# masked_image1939.jpg
# masked_image1940.jpg
# masked_image1941.jpg
# masked_image1942.jpg
# masked_image1943.jpg
# masked_image1944.jpg
# masked_image1946.jpg
# masked_image1949.jpg
# masked_image1950.jpg
# masked_image1951.jpg
# masked_image1952.jpg
# masked_image1953.jpg
# masked_image1954.jpg
# masked_image1955.jpg
# masked_image1957.jpg
# masked_image1959.jpg
# masked_image1960.jpg
# masked_image1961.jpg
# masked_image1962.jpg
# masked_image1963.jpg
# masked_image1964.jpg
# masked_image1965.jpg
# masked_image1966.jpg
# masked_image1967.jpg
# masked_image1969.jpg
# masked_image1970.jpg
# masked_image1971.jpg
# masked_image1972.jpg
# masked_image1976.jpg
# masked_image2063.jpg
# masked_image2064.jpg
# masked_image2081.jpg
# masked_image2083.jpg
# masked_image2085.jpg
# masked_image2087.jpg
# masked_image2089.jpg
# masked_image2091.jpg
# masked_image2095.jpg
# masked_image2096.jpg
# masked_image2098.jpg
# masked_image2103.jpg
# masked_image2104.jpg
# masked_image2106.jpg
# masked_image2107.jpg
# masked_image2115.jpg
# masked_image2116.jpg
# masked_image2137.jpg
# masked_image2138.jpg
# masked_image2139.jpg
# masked_image2140.jpg
# masked_image2142.jpg
# masked_image2143.jpg
# masked_image2144.jpg
# masked_image2146.jpg
# masked_image2148.jpg
# masked_image2149.jpg
# masked_image2169.jpg
# masked_image2170.jpg
# masked_image2171.jpg
# masked_image2172.jpg
# masked_image2175.jpg
# masked_image2176.jpg
# masked_image2185.jpg
# masked_image2187.jpg
# masked_image2190.jpg
# masked_image2191.jpg
# masked_image2192.jpg
# masked_image2194.jpg
# masked_image2195.jpg
# masked_image2198.jpg
# masked_image2202.jpg
# masked_image2226.jpg
# masked_image2234.jpg
# masked_image2238.jpg
# masked_image2239.jpg
# masked_image2243.jpg
# masked_image2244.jpg
# masked_image2246.jpg
# masked_image2247.jpg
# masked_image2248.jpg
# masked_image2250.jpg
# masked_image2260.jpg
# masked_image2261.jpg
# masked_image2262.jpg
# masked_image2272.jpg
# masked_image2274.jpg
# masked_image2276.jpg
# masked_image2280.jpg
# masked_image2281.jpg
# masked_image2316.jpg
# masked_image2317.jpg
# masked_image2318.jpg
# masked_image2334.jpg
# masked_image2344.jpg
# masked_image2367.jpg
# masked_image2368.jpg
# masked_image2370.jpg
# masked_image2371.jpg
# masked_image2372.jpg
# masked_image2373.jpg
# masked_image2374.jpg
# masked_image2381.jpg
# masked_image2382.jpg
# masked_image2383.jpg
# masked_image2384.jpg
# masked_image2386.jpg
# masked_image2387.jpg
# masked_image2388.jpg
# masked_image2392.jpg
# masked_image2393.jpg
# masked_image2394.jpg
# masked_image2396.jpg
# masked_image2397.jpg
# masked_image2400.jpg
# masked_image2401.jpg
# masked_image2402.jpg
# masked_image2403.jpg
# masked_image2405.jpg
# masked_image2406.jpg
# masked_image2407.jpg
# masked_image2408.jpg
# masked_image2409.jpg
# masked_image2410.jpg
# masked_image2411.jpg
# masked_image2412.jpg
# masked_image2414.jpg
# masked_image2415.jpg
# masked_image2416.jpg
# masked_image2417.jpg
# masked_image2418.jpg
# masked_image2420.jpg
# masked_image2421.jpg
# masked_image2423.jpg
# masked_image2424.jpg
# masked_image2425.jpg
# masked_image2426.jpg
# masked_image2427.jpg
# masked_image2428.jpg
# masked_image2430.jpg
# masked_image2431.jpg
# masked_image2433.jpg
# masked_image2434.jpg
# masked_image2435.jpg
# masked_image2436.jpg
# masked_image2437.jpg
# masked_image2440.jpg
# masked_image2442.jpg
# masked_image2443.jpg
# masked_image2444.jpg
# masked_image2452.jpg
# masked_image2453.jpg
# masked_image2454.jpg
# masked_image2455.jpg
# masked_image2456.jpg
# masked_image2457.jpg
# masked_image2461.jpg
# masked_image2462.jpg
# masked_image2464.jpg
# masked_image2467.jpg
# masked_image2468.jpg
# masked_image2469.jpg
# masked_image2470.jpg
# masked_image2471.jpg
# masked_image2475.jpg
# masked_image2476.jpg
# masked_image2479.jpg
# masked_image2481.jpg
# masked_image2486.jpg
# masked_image2488.jpg
# masked_image2489.jpg
# masked_image2508.jpg
# masked_image2509.jpg
# masked_image2510.jpg
# masked_image2511.jpg
# masked_image2512.jpg
# masked_image2514.jpg
# masked_image2515.jpg
# masked_image2521.jpg
# masked_image2523.jpg
# masked_image2524.jpg
# masked_image2525.jpg
# masked_image2526.jpg
# masked_image2527.jpg
# masked_image2528.jpg
# masked_image2536.jpg
# masked_image2537.jpg
# masked_image2539.jpg
# masked_image2556.jpg
# masked_image2557.jpg
# masked_image2559.jpg
# masked_image2560.jpg
# masked_image2561.jpg
# masked_image2562.jpg
# masked_image2563.jpg
# masked_image2564.jpg
# masked_image2565.jpg
# masked_image2566.jpg
# masked_image2571.jpg
# masked_image2573.jpg
# masked_image2575.jpg
# masked_image2576.jpg
# masked_image2584.jpg
# masked_image2586.jpg
# masked_image2587.jpg
# masked_image2588.jpg
# masked_image2589.jpg
# masked_image2591.jpg
# masked_image2594.jpg
# masked_image2595.jpg
# masked_image2597.jpg
# masked_image2598.jpg
# masked_image2602.jpg
# masked_image2603.jpg
# masked_image2605.jpg
# masked_image2606.jpg
# masked_image2607.jpg
# masked_image2611.jpg
# masked_image2612.jpg
# masked_image2613.jpg
# masked_image2615.jpg
# masked_image2616.jpg
# masked_image2617.jpg
# masked_image2618.jpg
# masked_image2619.jpg
# masked_image2620.jpg
# masked_image2621.jpg
# masked_image2624.jpg
# masked_image2626.jpg
# masked_image2627.jpg
# masked_image2628.jpg
# masked_image2629.jpg
# masked_image2630.jpg
# masked_image2631.jpg
# masked_image2632.jpg
# masked_image2634.jpg
# masked_image2635.jpg
# masked_image2636.jpg
# masked_image2637.jpg
# masked_image2642.jpg
# masked_image2643.jpg
# masked_image2644.jpg
# masked_image2645.jpg
# masked_image2646.jpg
# masked_image2647.jpg
# masked_image2649.jpg
# masked_image2652.jpg
# masked_image2653.jpg
# masked_image2654.jpg
# masked_image2655.jpg
# masked_image2657.jpg
# masked_image2658.jpg
# masked_image2659.jpg
# masked_image2660.jpg
# masked_image2661.jpg
# masked_image2662.jpg
# masked_image2663.jpg
# masked_image2664.jpg
# masked_image2665.jpg
# masked_image2666.jpg
# masked_image2669.jpg
# masked_image2670.jpg
# masked_image2671.jpg
# masked_image2672.jpg
# masked_image2674.jpg
# masked_image2675.jpg
# masked_image2677.jpg
# masked_image2680.jpg
# masked_image2681.jpg
# masked_image2682.jpg
# masked_image2685.jpg
# masked_image2686.jpg
# masked_image2687.jpg
# masked_image2688.jpg
# masked_image2689.jpg
# masked_image2690.jpg
# masked_image2691.jpg
# masked_image2692.jpg
# masked_image2693.jpg
# masked_image2695.jpg
# masked_image2696.jpg
# masked_image2699.jpg
# masked_image2700.jpg
# masked_image2704.jpg
# masked_image2706.jpg
# masked_image2708.jpg
# masked_image2711.jpg
# masked_image2712.jpg
# masked_image2714.jpg
# masked_image2716.jpg
# masked_image2717.jpg
# masked_image2718.jpg
# masked_image2720.jpg
# masked_image2721.jpg
# masked_image2722.jpg
# masked_image2723.jpg
# masked_image2725.jpg
# masked_image2726.jpg
# masked_image2727.jpg
# masked_image2728.jpg
# masked_image2729.jpg
# masked_image2731.jpg
# masked_image2732.jpg
# masked_image2733.jpg
# masked_image2734.jpg
# masked_image2735.jpg
# masked_image2736.jpg
# masked_image2737.jpg
# masked_image2738.jpg
# masked_image2740.jpg
# masked_image2742.jpg
# masked_image2743.jpg
# masked_image2744.jpg
# masked_image2745.jpg
# masked_image2746.jpg
# masked_image2750.jpg
# masked_image2753.jpg
# masked_image2759.jpg
# masked_image2766.jpg
# masked_image2767.jpg
# masked_image2769.jpg
# masked_image2770.jpg
# masked_image2773.jpg
# masked_image2774.jpg
# masked_image2778.jpg
# masked_image2780.jpg
# masked_image2782.jpg
# masked_image2783.jpg
# masked_image2784.jpg
# masked_image2787.jpg
# masked_image2788.jpg
# masked_image2790.jpg
# masked_image2793.jpg
# masked_image2794.jpg
# masked_image2796.jpg
# masked_image2797.jpg
# masked_image2798.jpg
# masked_image2800.jpg
# masked_image2801.jpg
# masked_image2802.jpg
# masked_image2805.jpg
# masked_image2806.jpg
# masked_image2807.jpg
# masked_image2808.jpg
# masked_image2811.jpg
# masked_image2812.jpg
# masked_image2813.jpg
# masked_image2815.jpg
# masked_image2816.jpg
# masked_image2820.jpg
# masked_image2822.jpg
# masked_image2824.jpg
# masked_image2827.jpg
# masked_image2828.jpg
# masked_image2829.jpg
# masked_image2831.jpg
# masked_image2833.jpg
# masked_image2834.jpg
# masked_image2835.jpg
# masked_image2837.jpg
# masked_image2840.jpg
# masked_image2842.jpg
# masked_image2843.jpg
# masked_image2844.jpg
# masked_image2845.jpg
# masked_image2846.jpg
# masked_image2849.jpg
# masked_image2850.jpg
# masked_image2851.jpg
# masked_image2853.jpg
# masked_image2854.jpg
# masked_image2856.jpg
# masked_image2861.jpg
# masked_image2862.jpg
# masked_image2864.jpg
# masked_image2866.jpg
# masked_image2867.jpg
# masked_image2868.jpg
# masked_image2869.jpg
# masked_image2872.jpg
# masked_image2873.jpg
# masked_image2874.jpg
# masked_image2875.jpg
# masked_image2876.jpg
# masked_image2879.jpg
# masked_image2880.jpg
# masked_image2881.jpg
# masked_image2882.jpg
# masked_image2884.jpg
# masked_image2885.jpg
# masked_image2888.jpg
# masked_image2891.jpg
# masked_image2892.jpg
# masked_image2893.jpg
# masked_image2894.jpg
# masked_image2895.jpg
# masked_image2896.jpg
# masked_image2897.jpg
# masked_image2899.jpg
# masked_image2900.jpg
# masked_image2901.jpg
# masked_image2903.jpg
# masked_image2904.jpg
# masked_image2906.jpg
# masked_image2907.jpg
# masked_image2908.jpg
# masked_image2910.jpg
# masked_image2911.jpg
# masked_image2912.jpg
# masked_image2913.jpg
# masked_image2914.jpg
# masked_image2915.jpg
# masked_image2916.jpg
# masked_image2917.jpg
# masked_image2920.jpg
# masked_image2921.jpg
# masked_image2923.jpg
# masked_image2924.jpg
# masked_image2925.jpg
# masked_image2928.jpg
# masked_image2930.jpg
# masked_image2932.jpg
# masked_image2933.jpg
# masked_image2934.jpg
# masked_image2936.jpg
# masked_image2937.jpg
# masked_image2938.jpg
# masked_image2940.jpg
# masked_image2941.jpg
# masked_image2942.jpg
# masked_image2944.jpg
# masked_image2945.jpg
# masked_image2946.jpg
# masked_image2947.jpg
# masked_image2951.jpg
# masked_image2952.jpg
# masked_image2953.jpg
# masked_image2954.jpg
# masked_image2955.jpg
# masked_image2956.jpg
# masked_image2957.jpg
# masked_image2958.jpg
# masked_image2959.jpg
# masked_image2960.jpg
# masked_image2961.jpg
# masked_image2964.jpg
# masked_image2965.jpg
# masked_image2966.jpg
# masked_image2970.jpg
# masked_image2971.jpg
# masked_image2974.jpg
# masked_image2975.jpg
# masked_image2976.jpg
# masked_image2979.jpg
# masked_image2981.jpg
# masked_image2982.jpg
# masked_image2983.jpg
# masked_image2984.jpg
# masked_image2986.jpg
# masked_image2988.jpg
# masked_image2989.jpg
# masked_image2990.jpg
# masked_image2991.jpg
# masked_image2992.jpg
# masked_image2993.jpg
# masked_image2994.jpg
# masked_image2997.jpg
# masked_image2999.jpg
# masked_image3001.jpg
# masked_image3005.jpg
# masked_image3006.jpg
# masked_image3007.jpg
# masked_image3010.jpg
# masked_image3011.jpg
# masked_image3014.jpg
# masked_image3015.jpg
# masked_image3017.jpg
# masked_image3019.jpg
# masked_image3022.jpg
# masked_image3024.jpg
# masked_image3028.jpg
# masked_image3029.jpg
# masked_image3030.jpg
# masked_image3031.jpg
# masked_image3032.jpg
# masked_image3033.jpg
# masked_image3034.jpg
# masked_image3035.jpg
# masked_image3037.jpg
# masked_image3038.jpg
# masked_image3039.jpg
# masked_image3040.jpg
# masked_image3041.jpg
# masked_image3042.jpg
# masked_image3043.jpg
# masked_image3044.jpg
# masked_image3045.jpg
# masked_image3046.jpg
# masked_image3048.jpg
# masked_image3050.jpg
# masked_image3051.jpg
# masked_image3052.jpg
# masked_image3054.jpg
# masked_image3055.jpg
# masked_image3056.jpg
# masked_image3057.jpg
# masked_image3058.jpg
# masked_image3060.jpg
# masked_image3061.jpg
# masked_image3062.jpg
# masked_image3064.jpg
# masked_image3065.jpg
# masked_image3066.jpg
# masked_image3069.jpg
# masked_image3070.jpg
# masked_image3073.jpg
# masked_image3074.jpg
# masked_image3075.jpg
# masked_image3076.jpg
# masked_image3078.jpg
# masked_image3080.jpg
# masked_image3081.jpg
# masked_image3082.jpg
# masked_image3083.jpg
# masked_image3084.jpg
# masked_image3087.jpg
# masked_image3090.jpg
# masked_image3091.jpg
# masked_image3093.jpg
# masked_image3094.jpg
# masked_image3095.jpg
# masked_image3096.jpg
# masked_image3097.jpg
# masked_image3099.jpg
# masked_image3100.jpg
# masked_image3102.jpg
# masked_image3103.jpg
# masked_image3104.jpg
# masked_image3105.jpg
# masked_image3106.jpg
# masked_image3108.jpg
# masked_image3110.jpg
# masked_image3112.jpg
# masked_image3113.jpg
# masked_image3115.jpg
# masked_image3116.jpg
# masked_image3117.jpg
# masked_image3118.jpg
# masked_image3120.jpg
# masked_image3121.jpg
# masked_image3122.jpg
# masked_image3123.jpg
# masked_image3124.jpg
# masked_image3125.jpg
# masked_image3126.jpg
# masked_image3127.jpg
# masked_image3128.jpg
# masked_image3129.jpg
# masked_image3132.jpg
# masked_image3133.jpg
# masked_image3134.jpg
# masked_image3136.jpg
# masked_image3138.jpg
# masked_image3139.jpg
# masked_image3140.jpg
# masked_image3141.jpg
# masked_image3142.jpg
# masked_image3143.jpg
# masked_image3145.jpg
# masked_image3146.jpg
# masked_image3148.jpg
# masked_image3149.jpg
# masked_image3151.jpg
# masked_image3153.jpg
# masked_image3155.jpg
# masked_image3156.jpg
# masked_image3157.jpg
# masked_image3158.jpg
# masked_image3159.jpg
# masked_image3160.jpg
# masked_image3161.jpg
# masked_image3162.jpg
# masked_image3163.jpg
# masked_image3164.jpg
# masked_image3166.jpg
# masked_image3167.jpg
# masked_image3170.jpg
# masked_image3171.jpg
# masked_image3172.jpg
# masked_image3174.jpg
# masked_image3175.jpg
# masked_image3176.jpg
# masked_image3178.jpg
# masked_image3179.jpg
# masked_image3180.jpg
# masked_image3181.jpg
# masked_image3182.jpg
# masked_image3183.jpg
# masked_image3184.jpg
# masked_image3185.jpg
# masked_image3186.jpg
# masked_image3188.jpg
# masked_image3189.jpg
# masked_image3190.jpg
# masked_image3192.jpg
# masked_image3193.jpg
# masked_image3194.jpg
# masked_image3196.jpg
# masked_image3198.jpg
# masked_image3199.jpg
# masked_image3201.jpg
# masked_image3202.jpg
# masked_image3203.jpg
# masked_image3204.jpg
# masked_image3207.jpg
# masked_image3210.jpg
# masked_image3211.jpg
# masked_image3212.jpg
# masked_image3213.jpg
# masked_image3214.jpg
# masked_image3215.jpg
# masked_image3216.jpg
# masked_image3218.jpg
# masked_image3219.jpg
# masked_image3220.jpg
# masked_image3222.jpg
# masked_image3223.jpg
# masked_image3224.jpg
# masked_image3225.jpg
# masked_image3226.jpg
# masked_image3227.jpg
# masked_image3228.jpg
# masked_image3229.jpg
# masked_image3230.jpg
# masked_image3233.jpg
# masked_image3234.jpg
# masked_image3235.jpg
# masked_image3237.jpg
# masked_image3238.jpg
# masked_image3239.jpg
# masked_image3242.jpg
# masked_image3244.jpg
# masked_image3245.jpg
# masked_image3246.jpg
# masked_image3248.jpg
# masked_image3249.jpg
# masked_image3251.jpg
# masked_image3254.jpg
# masked_image3255.jpg
# masked_image3257.jpg
# masked_image3258.jpg
# masked_image3259.jpg
# masked_image3261.jpg
# masked_image3262.jpg
# masked_image3263.jpg
# masked_image3265.jpg
# masked_image3266.jpg
# masked_image3268.jpg
# masked_image3269.jpg
# masked_image3271.jpg
# masked_image3272.jpg
# masked_image3275.jpg
# masked_image3276.jpg
# masked_image3277.jpg
# masked_image3278.jpg
# masked_image3279.jpg
# masked_image3280.jpg
# masked_image3281.jpg
# masked_image3284.jpg
# masked_image3285.jpg
# masked_image3286.jpg
# masked_image3288.jpg
# masked_image3290.jpg
# masked_image3291.jpg
# masked_image3294.jpg
# masked_image3295.jpg
# masked_image3297.jpg
# masked_image3298.jpg
# masked_image3299.jpg
# masked_image3300.jpg
# masked_image3301.jpg
# masked_image3304.jpg
# masked_image3306.jpg
# masked_image3307.jpg
# masked_image3308.jpg
# masked_image3309.jpg
# masked_image3310.jpg
# masked_image3312.jpg
# masked_image3313.jpg
# masked_image3315.jpg
# masked_image3317.jpg
# masked_image3319.jpg
# masked_image3320.jpg
# masked_image3321.jpg
# masked_image3322.jpg
# masked_image3323.jpg
# masked_image3324.jpg
# masked_image3325.jpg
# masked_image3326.jpg
# masked_image3327.jpg
# masked_image3329.jpg
# masked_image3333.jpg
# masked_image3336.jpg
# masked_image3337.jpg
# masked_image3338.jpg
# masked_image3339.jpg
# masked_image3343.jpg
# masked_image3345.jpg
# masked_image3347.jpg
# masked_image3350.jpg
# masked_image3351.jpg
# masked_image3352.jpg
# masked_image3353.jpg
# masked_image3354.jpg
# masked_image3355.jpg
# masked_image3356.jpg
# masked_image3357.jpg
# masked_image3358.jpg
# masked_image3359.jpg
# masked_image3360.jpg
# masked_image3362.jpg
# masked_image3363.jpg
# masked_image3367.jpg
# masked_image3371.jpg
# masked_image3372.jpg
# masked_image3373.jpg
# masked_image3376.jpg
# masked_image3377.jpg
# masked_image3379.jpg
# masked_image3380.jpg
# masked_image3381.jpg
# masked_image3382.jpg
# masked_image3383.jpg
# masked_image3384.jpg
# masked_image3385.jpg
# masked_image3387.jpg
# masked_image3388.jpg
# masked_image3389.jpg
# masked_image3390.jpg
# masked_image3392.jpg
# masked_image3394.jpg
# masked_image3395.jpg
# masked_image3396.jpg
# masked_image3397.jpg
# masked_image3398.jpg
# masked_image3400.jpg
# masked_image3401.jpg
# masked_image3402.jpg
# masked_image3403.jpg
# masked_image3404.jpg
# masked_image3405.jpg
# masked_image3407.jpg
# masked_image3408.jpg
# masked_image3409.jpg
# masked_image3411.jpg
# masked_image3413.jpg
# masked_image3414.jpg
# masked_image3416.jpg
# masked_image3417.jpg
# masked_image3418.jpg
# masked_image3420.jpg
# masked_image3422.jpg
# masked_image3423.jpg
# masked_image3424.jpg
# masked_image3425.jpg
# masked_image3426.jpg
# masked_image3427.jpg
# masked_image3428.jpg
# masked_image3429.jpg
# masked_image3430.jpg
# masked_image3431.jpg
# masked_image3432.jpg
# masked_image3433.jpg
# masked_image3434.jpg
# masked_image3435.jpg
# masked_image3436.jpg
# masked_image3438.jpg
# masked_image3440.jpg
# masked_image3441.jpg
# masked_image3442.jpg
# masked_image3443.jpg
# masked_image3444.jpg
# masked_image3445.jpg
# masked_image3446.jpg
# masked_image3447.jpg
# masked_image3449.jpg
# masked_image3450.jpg
# masked_image3452.jpg
# masked_image3453.jpg
# masked_image3454.jpg
# masked_image3455.jpg
# masked_image3457.jpg
# masked_image3459.jpg
# masked_image3460.jpg
# masked_image3462.jpg
# masked_image3463.jpg
# masked_image3469.jpg
# masked_image3470.jpg
# masked_image3471.jpg
# masked_image3474.jpg
# masked_image3475.jpg
# masked_image3476.jpg
# masked_image3478.jpg
# masked_image3479.jpg
# masked_image3480.jpg
# masked_image3481.jpg
# masked_image3482.jpg
# masked_image3483.jpg
# masked_image3484.jpg
# masked_image3485.jpg
# masked_image3486.jpg
# masked_image3488.jpg
# masked_image3491.jpg
# masked_image3492.jpg
# masked_image3493.jpg
# masked_image3494.jpg
# masked_image3495.jpg
# masked_image3498.jpg
# masked_image3499.jpg
# masked_image3500.jpg
# masked_image3502.jpg
# masked_image3503.jpg
# masked_image3504.jpg
# masked_image3508.jpg
# masked_image3510.jpg
# masked_image3511.jpg
# masked_image3512.jpg
# masked_image3513.jpg
# masked_image3514.jpg
# masked_image3517.jpg
# masked_image3519.jpg
# masked_image3521.jpg
# masked_image3522.jpg
# masked_image3523.jpg
# masked_image3524.jpg
# masked_image3525.jpg
# masked_image3526.jpg
# masked_image3529.jpg
# masked_image3531.jpg
# masked_image3532.jpg
# masked_image3534.jpg
# masked_image3535.jpg
# masked_image3536.jpg
# masked_image3537.jpg
# masked_image3538.jpg
# masked_image3539.jpg
# masked_image3540.jpg
# masked_image3541.jpg
# masked_image3542.jpg
# masked_image3543.jpg
# masked_image3548.jpg
# masked_image3549.jpg
# masked_image3551.jpg
# masked_image3552.jpg
# masked_image3553.jpg
# masked_image3554.jpg
# masked_image3558.jpg
# masked_image3560.jpg
# masked_image3561.jpg
# masked_image3563.jpg
# masked_image3566.jpg
# masked_image3567.jpg
# masked_image3568.jpg
# masked_image3570.jpg
# masked_image3571.jpg
# masked_image3573.jpg
# masked_image3574.jpg
# masked_image3575.jpg
# masked_image3577.jpg
# masked_image3578.jpg
# masked_image3581.jpg
# masked_image3583.jpg
# masked_image3584.jpg
# masked_image3587.jpg
# masked_image3589.jpg
# masked_image3590.jpg
# masked_image3591.jpg
# masked_image3593.jpg
# masked_image3594.jpg
# masked_image3595.jpg
# masked_image3596.jpg
# masked_image3598.jpg
# masked_image3599.jpg
# masked_image3600.jpg
# masked_image3601.jpg
# masked_image3602.jpg
# masked_image3603.jpg
# masked_image3604.jpg
# masked_image3605.jpg
# masked_image3606.jpg
# masked_image3607.jpg
# masked_image3608.jpg
# masked_image3609.jpg
# masked_image3610.jpg
# masked_image3611.jpg
# masked_image3612.jpg
# masked_image3613.jpg
# masked_image3614.jpg
# masked_image3615.jpg
# masked_image3616.jpg
# masked_image3617.jpg
# masked_image3618.jpg
# masked_image3620.jpg
# masked_image3621.jpg
# masked_image3622.jpg
# masked_image3625.jpg
# masked_image3629.jpg
# masked_image3630.jpg
# masked_image3632.jpg
# masked_image3633.jpg
# masked_image3634.jpg
# masked_image3637.jpg
# masked_image3639.jpg
# masked_image3640.jpg
# masked_image3644.jpg
# masked_image3645.jpg
# masked_image3646.jpg
# masked_image3649.jpg
# masked_image3650.jpg
# masked_image3651.jpg
# masked_image3652.jpg
# masked_image3653.jpg
# masked_image3655.jpg
# masked_image3656.jpg
# masked_image3659.jpg
# masked_image3661.jpg
# masked_image3662.jpg
# masked_image3663.jpg
# masked_image3664.jpg
# masked_image3665.jpg
# masked_image3666.jpg
# masked_image3670.jpg
# masked_image3671.jpg
# masked_image3672.jpg
# masked_image3674.jpg
# masked_image3675.jpg
# masked_image3676.jpg
# masked_image3677.jpg
# masked_image3678.jpg
# masked_image3679.jpg
# masked_image3680.jpg
# masked_image3681.jpg
# masked_image3684.jpg
# masked_image3685.jpg
# masked_image3686.jpg
# masked_image3688.jpg
# masked_image3689.jpg
# masked_image3691.jpg
# masked_image3692.jpg
# masked_image3694.jpg
# masked_image3695.jpg
# masked_image3696.jpg
# masked_image3697.jpg
# masked_image3698.jpg
# masked_image3699.jpg
# masked_image3701.jpg
# masked_image3702.jpg
# masked_image3703.jpg
# masked_image3706.jpg
# masked_image3709.jpg
# masked_image3710.jpg
# masked_image3711.jpg
# masked_image3713.jpg
# masked_image3715.jpg
# masked_image3716.jpg
# masked_image3717.jpg
# masked_image3718.jpg
# masked_image3719.jpg
# masked_image3721.jpg
# masked_image3722.jpg
# masked_image3723.jpg
# masked_image3724.jpg
# masked_image3725.jpg
# masked_image3727.jpg
# masked_image3728.jpg
# masked_image3729.jpg
# masked_image3730.jpg
# masked_image3731.jpg
# masked_image3732.jpg
# masked_image3733.jpg
# masked_image3735.jpg
# masked_image3736.jpg
# masked_image3738.jpg
# masked_image3741.jpg
# masked_image3742.jpg
# masked_image3744.jpg
# masked_image3745.jpg
# masked_image3747.jpg
# masked_image3749.jpg
# masked_image3750.jpg
# masked_image3754.jpg
# masked_image3755.jpg
# masked_image3759.jpg
# masked_image3760.jpg
# masked_image3761.jpg
# masked_image3762.jpg
# masked_image3766.jpg
# masked_image3767.jpg
# masked_image3768.jpg
# masked_image3769.jpg
# masked_image3770.jpg
# masked_image3771.jpg
# masked_image3774.jpg
# masked_image3775.jpg
# masked_image3776.jpg
# masked_image3777.jpg
# masked_image3780.jpg
# masked_image3781.jpg
# masked_image3782.jpg
# masked_image3784.jpg
# masked_image3785.jpg
# masked_image3786.jpg
# masked_image3787.jpg
# masked_image3788.jpg
# masked_image3789.jpg
# masked_image3792.jpg
# masked_image3793.jpg
# masked_image3794.jpg
# masked_image3797.jpg
# masked_image3798.jpg
# masked_image3799.jpg
# masked_image3800.jpg
# masked_image3802.jpg
# masked_image3803.jpg
# masked_image3804.jpg
# masked_image3805.jpg
# masked_image3807.jpg
# masked_image3810.jpg
# masked_image3812.jpg
# masked_image3813.jpg
# masked_image3814.jpg
# masked_image3816.jpg
# masked_image3817.jpg
# masked_image3818.jpg
# masked_image3821.jpg
# masked_image3822.jpg
# masked_image3823.jpg
# masked_image3825.jpg
# masked_image3826.jpg
# masked_image3827.jpg
# masked_image3828.jpg
# masked_image3830.jpg
# masked_image3833.jpg
# masked_image3835.jpg
# masked_image3836.jpg
# masked_image3837.jpg
# masked_image3838.jpg
# masked_image3839.jpg
# masked_image3840.jpg
# masked_normal_1.jpg
# masked_normal_13.jpg
# masked_normal_15.jpg
# masked_normal_18.jpg
# masked_normal_23.jpg
# masked_normal_24.jpg
# masked_normal_25.jpg
# masked_normal_26.jpg
# masked_normal_27.jpg
# masked_normal_28.jpg
# masked_normal_29.jpg
# masked_normal_3.jpg
# masked_normal_32.jpg
# masked_normal_33.jpg
# masked_normal_34.jpg
# masked_normal_35.jpg
# masked_normal_36.jpg
# masked_normal_37.jpg
# masked_normal_39.jpg
# masked_normal_4.jpg
# masked_normal_5.jpg
# masked_normal_6.jpg
# masked_normal_8.jpg
# masked_normal_9.jpg
# masked_pco_1.jpg
# masked_pco_10.jpg
# masked_pco_11.jpg
# masked_pco_13.jpg
# masked_pco_14.jpg
# masked_pco_2.jpg
# masked_pco_3.jpg
# masked_pco_4.jpg
# masked_pco_5.jpg
# masked_pco_6.jpg
# masked_pco_7.jpg
# masked_pco_8.jpg
# 128 128 3
#
#
# 128 128 1
# X Shape: (2560, 128, 128, 3)

# %%
''' 5 - Evaluate Model Results'''

## 5.1 - Bias Variance Check

# High Bias is a characteristic of an underfitted model and we would observe low accuracies for both train and validation set
# High Variance is a characterisitic of an overfitted model and we would observe high accuracy for train set and low for validation set
# To check for bias and variance plit the graphs for accuracy
# I have plotted for loss too, this helps in confirming if the loss is decreasing with each iteration - hence, the model is optimizing fine
fig, axis = plt.subplots(1, 2, figsize = (20, 5))
axis[0].plot(results.history["loss"], color = 'r', label = 'train loss')
axis[0].plot(results.history["val_loss"], color = 'b', label = 'dev loss')
axis[0].set_title('Loss Comparison')
axis[0].legend()
axis[1].plot(results.history["accuracy"], color = 'r', label = 'train accuracy')
axis[1].plot(results.history["val_accuracy"], color = 'b', label = 'dev accuracy')
axis[1].set_title('Accuracy Comparison')
axis[1].legend()

# RESULTS
# The train loss is consistently decreasing showing that Adam is able to optimize the model and find the minima
# The accuracy of train and validation is ~90% which is high enough, so low bias
# and the %s aren't that far apart, hence low variance

## 5.2 - View Predicted Segmentations

unet.evaluate(X_valid, y_valid)

# Results of Validation Dataset
def VisualizeResults(index):
    img = X_valid[index]
    img = img[np.newaxis, ...]
    pred_y = unet.predict(img)
    pred_mask = tf.argmax(pred_y[0], axis = -1)
    pred_mask = pred_mask[..., tf.newaxis]
    fig, arr = plt.subplots(1, 3, figsize = (15, 15))
    arr[0].imshow(X_valid[index])
    arr[0].set_title('Processed Image')
    arr[1].imshow(y_valid[index, :, :, 0])
    arr[1].set_title('Actual Masked Image ')
    arr[2].imshow(pred_mask[:, :, 0])
    arr[2].set_title('Predicted Masked Image ')

# Add any index to contrast the predicted mask with actual mask
index = 700
VisualizeResults(index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 10
#       3 ## 5.1 - Bias Variance Check
#       4
#       5 # High Bias is a characteristic of an underfitted model and we would observe low accuracies for both train and validation set
#       6 # High Variance is a characterisitic of an overfitted model and we would observe high accuracy for train set and low for validation set
#       7 # To check for bias and variance plit the graphs for accuracy
#       8 # I have plotted for loss too, this helps in confirming if the loss is decreasing with each iteration - hence, the model is optimizing fine
#       9 fig, axis = plt.subplots(1, 2, figsize = (20, 5))
# ---> 10 axis[0].plot(results.history["loss"], color = 'r', label = 'train loss')
#      11 axis[0].plot(results.history["val_loss"], color = 'b', label = 'dev loss')
#      12 axis[0].set_title('Loss Comparison')
#
# NameError: name 'results' is not defined
